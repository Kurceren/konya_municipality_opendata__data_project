# %%
import pandas as pd
import numpy as np

# %%
df17=pd.read_csv("yangin_sayi_ve_sebepleri_2017.csv")
df18=pd.read_csv("yangin_sayi_ve_sebepleri_2018.csv")
df19=pd.read_csv("yangin_sayi_ve_sebepleri_2019.csv")
df20=pd.read_csv("yangin_sayi_ve_sebepleri_2020.csv")
df21=pd.read_csv("yangin_sayi_ve_sebepleri_2017.csv")

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ilceler                    29 non-null     object
#  1   elektrik_kontagi           29 non-null     int64
#  2   lpg/dogalgaz               29 non-null     int64
#  3   ocak/soba/kalorifer/kazan  29 non-null     int64
#  4   baca_tutusmasi             29 non-null     int64
#  5   sigara/kibrit              29 non-null     int64
#  6   akaryakit                  29 non-null     int64
#  7   patlayici_madde            29 non-null     int64
#  8   yildirim_dusmesi           29 non-null     int64
#  9   sabotaj                    29 non-null     int64
#  10  diger                      29 non-null     int64
#  11  anlasilamadi               29 non-null     int64
#  12  toplam                     29 non-null     int64
# dtypes: int64(12), object(1)
# ...

# %%
column_names17 = df17.columns.tolist()
column_names18 = df18.columns.tolist()
column_names19 = df19.columns.tolist()
column_names20 = df20.columns.tolist()
column_names21 = df21.columns.tolist()

hepsi=[column_names17,column_names18,column_names19,column_names20,column_names21]

# %%
hepsi
# Out:
# [['ilceler',
#   'elektrik_kontagi',
#   'lpg/dogalgaz',
#   'ocak/soba/kalorifer/kazan',
#   'baca_tutusmasi',
#   'sigara/kibrit',
#   'akaryakit',
#   'patlayici_madde',
#   'yildirim_dusmesi',
#   'sabotaj',
#   'diger',
#   'anlasilamadi',
#   'toplam'],
#  ['ilceler',
#   'elektrik_kontagi',
#   'lpg/dogalgaz',
#   'ocak/soba/kalorifer/kazan',
#   'baca_tutusmasi',
#   'sigara/kibrit',
#   'akaryakit',
#   'patlayici_madde',
#   'yildirim_dusmesi',
#   'sabotaj',
#   'diger',
#   'anlasilamadi',
#   'toplam'],
#  ['ilceler',
#   'elektrik_kontagi',
#   'lpg/dogalgaz',
#   'ocak/soba/kalorifer/kazan',
#   'baca_tutusmasi',
#   'sigara/kibrit',
#   'akaryakit',
#   'patlayici_madde',
#   'yildirim_dusmesi',
#   'sabotaj',
#   'diger',
#   'anlasilamadi',
#   'toplam'],
#  ['ilceler',
#   'elektrik_kontagi',
#   'lpg/dogalgaz',
#   'ocak/soba/kalorifer/kazan',
#   'baca_tutusmasi',
#   'sigara/kibrit',
#   'akaryakit',
#   'patlayici_madde',
#   'yildirim_dusmesi',
#   'sabotaj',
# ...

# %%
column_names21
# Out:
# ['ilceler',
#  'elektrik_kontagi',
#  'lpg/dogalgaz',
#  'ocak/soba/kalorifer/kazan',
#  'baca_tutusmasi',
#  'sigara/kibrit',
#  'akaryakit',
#  'patlayici_madde',
#  'yildirim_dusmesi',
#  'sabotaj',
#  'diger',
#  'anlasilamadi',
#  'toplam']

# %%
column_names18[1]
# Out:
# 'elektrik_kontagi'

# %%
for x in range(12):
    if column_names17[x]==column_names18[x] and column_names17[x]==column_names19[x]:

        

            if column_names17[x]==column_names20[x] and column_names17[x]==column_names21[x]:

                
                print("aynı")
            else:
                    print("a")
        
    else:
        print("a")
# Out:
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı
# aynı

# %%
column_to_check = 'ilceler'

# Tüm satırların aynı olup olmadığını kontrol eden döngü
for i in range(1, len(hepsi)):
    if hepsi[i][column_to_check].equals(hepsi[0][column_to_check]):
        print(f"hepsi-{i+1} ve hepsi-1, '{column_to_check}' sütunlarında tüm satırlar aynıdır.")
    else:
        print(f"hepsi-{i+1} ve hepsi-1, '{column_to_check}' sütunlarında farklı satırlara sahiptir.")
# Out:
# hepsi-2 ve hepsi-1, 'ilceler' sütunlarında tüm satırlar aynıdır.
# hepsi-3 ve hepsi-1, 'ilceler' sütunlarında tüm satırlar aynıdır.
# hepsi-4 ve hepsi-1, 'ilceler' sütunlarında tüm satırlar aynıdır.
# hepsi-5 ve hepsi-1, 'ilceler' sütunlarında tüm satırlar aynıdır.

# %%
df17
# Out:
#        ilceler  elektrik_kontagi  lpg/dogalgaz  ocak/soba/kalorifer/kazan  \
# 0     SELÇUKLU               155             7                         20
# 1        MERAM               133             4                         34
# 2      KARATAY                75            11                         18
# 3       SANCAK                 0             0                          0
# 4       AKÖREN                 2             0                          0
# 5      AKŞEHİR                35             2                         10
# 6    ALTINEKİN                 3             0                          2
# 7     BEYŞEHİR                 8             5                          6
# 8       BOZKIR                 6             0                          0
# 9   CİHANBEYLİ                13             0                          4
# 10      ÇELTİK                12             0                          1
# 11       ÇUMRA                36             2                         17
# ...

# %%
summ17= np.sum(df17, axis=1)
summ17=summ17 - df17["toplam"]


summ18= np.sum(df18, axis=1)
summ18=summ18 - df18["toplam"]


summ19= np.sum(df19, axis=1)
summ19=summ19 - df19["toplam"]


summ20= np.sum(df20, axis=1)
summ20=summ20 - df20["toplam"]


summ21= np.sum(df21, axis=1)
summ21=summ21 - df21["toplam"]
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
tplm=df17["toplam"]
iii=0
for x in tplm.index:
    if summ17[x]!=tplm[x]:
        print("a")
    else:
        iii=1

if iii==1:
    print("True")
# Out:
# True

# %%
tplm=df18["toplam"]
iii=0
for x in tplm.index:
    if summ18[x]!=tplm[x]:
        print("a")
    else:
        iii=1

if iii==1:
    print("True")
# Out:
# True

# %%
tplm=df19["toplam"]
iii=0
for x in tplm.index:
    if summ19[x]!=tplm[x]:
        print("a")
    else:
        iii=1

if iii==1:
    print("True")
# Out:
# True

# %%
tplm=df20["toplam"]
iii=0
for x in tplm.index:
    if summ20[x]!=tplm[x]:
        print("a")
    else:
        iii=1

if iii==1:
    print("True")
# Out:
# True

# %%
tplm=df21["toplam"]
iii=0
for x in tplm.index:
    if summ21[x]!=tplm[x]:
        print("a")
    else:
        iii=1

if iii==1:
    print("True")
# Out:
# True

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ilceler                    29 non-null     object
#  1   elektrik_kontagi           29 non-null     int64
#  2   lpg/dogalgaz               29 non-null     int64
#  3   ocak/soba/kalorifer/kazan  29 non-null     int64
#  4   baca_tutusmasi             29 non-null     int64
#  5   sigara/kibrit              29 non-null     int64
#  6   akaryakit                  29 non-null     int64
#  7   patlayici_madde            29 non-null     int64
#  8   yildirim_dusmesi           29 non-null     int64
#  9   sabotaj                    29 non-null     int64
#  10  diger                      29 non-null     int64
#  11  anlasilamadi               29 non-null     int64
#  12  toplam                     29 non-null     int64
# dtypes: int64(12), object(1)
# ...

# %%
type(df17["ilceler"][0])
# Out:
# str

# %%
df17.to_csv("temiz_17.csv",header=True ,index=False)
df17.to_excel("temiz_17.xlsx",header=True ,index=False)

# %%
df2017e=pd.read_excel("temiz_17.xlsx")

# %%
df2017e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ilceler                    29 non-null     object
#  1   elektrik_kontagi           29 non-null     int64
#  2   lpg/dogalgaz               29 non-null     int64
#  3   ocak/soba/kalorifer/kazan  29 non-null     int64
#  4   baca_tutusmasi             29 non-null     int64
#  5   sigara/kibrit              29 non-null     int64
#  6   akaryakit                  29 non-null     int64
#  7   patlayici_madde            29 non-null     int64
#  8   yildirim_dusmesi           29 non-null     int64
#  9   sabotaj                    29 non-null     int64
#  10  diger                      29 non-null     int64
#  11  anlasilamadi               29 non-null     int64
#  12  toplam                     29 non-null     int64
# dtypes: int64(12), object(1)
# ...
