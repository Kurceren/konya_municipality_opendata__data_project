# %%
import pandas as pd

# %%
df=pd.read_csv("yangin_sayi_ve_sebepleri_2017.csv")

# %%
df
# Out:
#        ilceler  elektrik_kontagi  lpg/dogalgaz  ocak/soba/kalorifer/kazan  \
# 0     SELÇUKLU               155             7                         20
# 1        MERAM               133             4                         34
# 2      KARATAY                75            11                         18
# 3       SANCAK                 0             0                          0
# 4       AKÖREN                 2             0                          0
# 5      AKŞEHİR                35             2                         10
# 6    ALTINEKİN                 3             0                          2
# 7     BEYŞEHİR                 8             5                          6
# 8       BOZKIR                 6             0                          0
# 9   CİHANBEYLİ                13             0                          4
# 10      ÇELTİK                12             0                          1
# 11       ÇUMRA                36             2                         17
# ...
