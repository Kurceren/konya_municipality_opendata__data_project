# %%
import pandas as pd

# %%
df=pd.read_csv("49_202103_wifi_noktalar.csv", sep=";")

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
pd.options.display.max_rows = None

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
df["1_enlem"]=df["1.erisim_koordinat"]
df["1_boylam"]=df["1.erisim_koordinat"]
df["2_enlem"]=df["no"]
df["2_boylam"]=df["no"]

# %%
for x in df["no"].index:
    y=df["1.erisim_koordinat"][x].split(",")
    df["1_enlem"][x]=y[0]
    df["1_boylam"][x]=y[1]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1756\3562052283.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["1_enlem"][x]=y[0]
# C:\Users\User\AppData\Local\Temp\ipykernel_1756\3562052283.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["1_boylam"][x]=y[1]

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
df=df.drop(columns="1.erisim_koordinat")

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   no                           80 non-null     int64
#  1   ucretsiz_wifi_noktalari_adi  80 non-null     object
#  2   2._erisim_koordinat          4 non-null      object
#  3   1_enlem                      80 non-null     object
#  4   1_boylam                     80 non-null     object
#  5   2_enlem                      80 non-null     int64
#  6   2_boylam                     80 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 4.5+ KB

# %%
df["1_enlem"]=df["1_enlem"].astype("Float64")
df["1_boylam"]=df["1_boylam"].astype("Float64")
df["2_enlem"]=df["2_enlem"].astype("string")
df["2_boylam"]=df["2_boylam"].astype("string")

# %%
df["2._erisim_koordinat"]=df["2._erisim_koordinat"].astype("string")

# %%
df.fillna("1,1", inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   no                           80 non-null     int64
#  1   ucretsiz_wifi_noktalari_adi  80 non-null     object
#  2   2._erisim_koordinat          80 non-null     string
#  3   1_enlem                      80 non-null     Float64
#  4   1_boylam                     80 non-null     Float64
#  5   2_enlem                      80 non-null     string
#  6   2_boylam                     80 non-null     string
# dtypes: Float64(2), int64(1), object(1), string(3)
# memory usage: 4.7+ KB

# %%
for x in df["no"].index:
    y=df["2._erisim_koordinat"][x].split(",")
    df["2_enlem"][x]=y[0]
    df["2_boylam"][x]=y[1]

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
for y in df["2._erisim_koordinat"].index:
    if df["2._erisim_koordinat"][x]=="1":
        df["2_boylam"][x]= None
        df["2_enlem"][x]= None

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
df=df.replace("1",None)

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi  \
# 0    1                         Eski SGK Binası
# 1    2     Başkanlık Özel Kalem (Alman Evleri)
# 2    3                        Elkart Müdürlüğü
# 3    4             Fen İşleri Daire Başkanlığı
# 4    5                     Millet Kıraathanesi
# 5    6      İrfan Medeniyeti Araştırma Merkezi
# 6    7                       KültürPark Zabıta
# 7    8                    Mezar Taşları Müzesi
# 8    9                  Mevlana Kültür Merkezi
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina
# 10  11           Raylı Sistem Daire Başkanlığı
# 11  12                      Tarımsal Hizmetler
# 12  13                      Tatlıcak Tesisleri
# 13  14                        Aydınlık İtfaiye
# 14  15                           Hayvan Pazarı
# 15  16                        Kültürpark Kadem
# 16  17             Kılıçarslan Toplantı Salonu
# 17  18                        Koyunoğlu Müzesi
# 18  19                          Sanat Galerisi
# ...

# %%
df=df.drop(columns="2._erisim_koordinat")

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi    1_enlem   1_boylam  \
# 0    1                         Eski SGK Binası  37.870055  32.482229
# 1    2     Başkanlık Özel Kalem (Alman Evleri)  37.869196  32.477103
# 2    3                        Elkart Müdürlüğü  37.873734  32.487142
# 3    4             Fen İşleri Daire Başkanlığı  37.937266  32.512032
# 4    5                     Millet Kıraathanesi  37.874856  32.489072
# 5    6      İrfan Medeniyeti Araştırma Merkezi  37.870301  32.511059
# 6    7                       KültürPark Zabıta  37.875132  32.487602
# 7    8                    Mezar Taşları Müzesi  37.867368  32.512122
# 8    9                  Mevlana Kültür Merkezi  37.869484  32.515774
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina  37.902135  32.498297
# 10  11           Raylı Sistem Daire Başkanlığı  37.918236  32.507006
# 11  12                      Tarımsal Hizmetler  37.874255  32.486216
# 12  13                      Tatlıcak Tesisleri  37.868926  32.573669
# ...

# %%
for col in df.columns:
    if col=="2_enlem":
        df[col] = pd.to_numeric(df[col], errors='coerce').astype('float64')
    if col=="2_boylam":
        df[col] = pd.to_numeric(df[col], errors='coerce').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   no                           80 non-null     int64
#  1   ucretsiz_wifi_noktalari_adi  80 non-null     object
#  2   1_enlem                      80 non-null     Float64
#  3   1_boylam                     80 non-null     Float64
#  4   2_enlem                      4 non-null      float64
#  5   2_boylam                     4 non-null      float64
# dtypes: Float64(2), float64(2), int64(1), object(1)
# memory usage: 4.0+ KB

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi    1_enlem   1_boylam  \
# 0    1                         Eski SGK Binası  37.870055  32.482229
# 1    2     Başkanlık Özel Kalem (Alman Evleri)  37.869196  32.477103
# 2    3                        Elkart Müdürlüğü  37.873734  32.487142
# 3    4             Fen İşleri Daire Başkanlığı  37.937266  32.512032
# 4    5                     Millet Kıraathanesi  37.874856  32.489072
# 5    6      İrfan Medeniyeti Araştırma Merkezi  37.870301  32.511059
# 6    7                       KültürPark Zabıta  37.875132  32.487602
# 7    8                    Mezar Taşları Müzesi  37.867368  32.512122
# 8    9                  Mevlana Kültür Merkezi  37.869484  32.515774
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina  37.902135  32.498297
# 10  11           Raylı Sistem Daire Başkanlığı  37.918236  32.507006
# 11  12                      Tarımsal Hizmetler  37.874255  32.486216
# 12  13                      Tatlıcak Tesisleri  37.868926  32.573669
# ...

# %%
df["ucretsiz_wifi_noktalari_adi"]=df["ucretsiz_wifi_noktalari_adi"].astype("string")

# %%
df
# Out:
#     no             ucretsiz_wifi_noktalari_adi    1_enlem   1_boylam  \
# 0    1                         Eski SGK Binası  37.870055  32.482229
# 1    2     Başkanlık Özel Kalem (Alman Evleri)  37.869196  32.477103
# 2    3                        Elkart Müdürlüğü  37.873734  32.487142
# 3    4             Fen İşleri Daire Başkanlığı  37.937266  32.512032
# 4    5                     Millet Kıraathanesi  37.874856  32.489072
# 5    6      İrfan Medeniyeti Araştırma Merkezi  37.870301  32.511059
# 6    7                       KültürPark Zabıta  37.875132  32.487602
# 7    8                    Mezar Taşları Müzesi  37.867368  32.512122
# 8    9                  Mevlana Kültür Merkezi  37.869484  32.515774
# 9   10  Park Bahçe Daire Başkanlığı İdari Bina  37.902135  32.498297
# 10  11           Raylı Sistem Daire Başkanlığı  37.918236  32.507006
# 11  12                      Tarımsal Hizmetler  37.874255  32.486216
# 12  13                      Tatlıcak Tesisleri  37.868926  32.573669
# ...

# %%
df.to_excel("temiz_wifi_noktaları_excel.xlsx",index=False ,header=True)
df.to_csv("temiz_wifi_noktaları_csv.csv",index=False ,header=True)
