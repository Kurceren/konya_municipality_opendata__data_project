# %%
import pandas as pd

# %%
df=pd.read_csv("100_202106_aricilik.csv",sep=";")

# %%
df
# Out:
#     ilce_adi mahalle_adi aricilik
# 0     Ahırlı    ALİÇERÇİ    HAYIR
# 1     Ahırlı     BADEMLİ     EVET
# 2     Ahırlı   BALIKLAVA     EVET
# 3     Ahırlı     BÜYÜKÖZ     EVET
# 4     Ahırlı     ÇİFTLİK     EVET
# ..       ...         ...      ...
# 768    Yunak    YEŞİLOBA    HAYIR
# 769    Yunak  YEŞİLYAYLA     EVET
# 770    Yunak       YIĞAR    HAYIR
# 771    Yunak       SARAY     EVET
# 772      NaN         NaN      NaN
#
# [773 rows x 3 columns]

# %%
df.to_csv("lolay.csv")

# %%
df.fillna(1)
# Out:
#     ilce_adi mahalle_adi aricilik
# 0     Ahırlı    ALİÇERÇİ    HAYIR
# 1     Ahırlı     BADEMLİ     EVET
# 2     Ahırlı   BALIKLAVA     EVET
# 3     Ahırlı     BÜYÜKÖZ     EVET
# 4     Ahırlı     ÇİFTLİK     EVET
# ..       ...         ...      ...
# 768    Yunak    YEŞİLOBA    HAYIR
# 769    Yunak  YEŞİLYAYLA     EVET
# 770    Yunak       YIĞAR    HAYIR
# 771    Yunak       SARAY     EVET
# 772        1           1        1
#
# [773 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#        ilce_adi       mahalle_adi aricilik
# 0        Ahırlı          ALİÇERÇİ    HAYIR
# 1        Ahırlı           BADEMLİ     EVET
# 2        Ahırlı         BALIKLAVA     EVET
# 3        Ahırlı           BÜYÜKÖZ     EVET
# 4        Ahırlı           ÇİFTLİK     EVET
# 5        Ahırlı           ERDOĞAN     EVET
# 6        Ahırlı        KARACAKUYU     EVET
# 7        Ahırlı           KAYACIK     EVET
# 8        Ahırlı           KURUÇAY     EVET
# 9        Ahırlı           KÜÇÜKÖZ    HAYIR
# 10       Akören             AVDAN     EVET
# 11       Akören            KAYASU     EVET
# 12       Akören          AHMEDİYE     EVET
# 13       Akören              ALAN     EVET
# 14       Akören           BELKUYU     EVET
# 15       Akören           ÇATÖREN     EVET
# 16       Akören             DUTLU    HAYIR
# 17       Akören          ORHANİYE     EVET
# 18       Akören       SÜLEYMANİYE     EVET
# 19       Akören             TÜLCE     EVET
# 20       Akören         KARAHÜYÜK     EVET
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#        ilce_adi       mahalle_adi aricilik
# 0        Ahırlı          ALİÇERÇİ    HAYIR
# 1        Ahırlı           BADEMLİ     EVET
# 2        Ahırlı         BALIKLAVA     EVET
# 3        Ahırlı           BÜYÜKÖZ     EVET
# 4        Ahırlı           ÇİFTLİK     EVET
# 5        Ahırlı           ERDOĞAN     EVET
# 6        Ahırlı        KARACAKUYU     EVET
# 7        Ahırlı           KAYACIK     EVET
# 8        Ahırlı           KURUÇAY     EVET
# 9        Ahırlı           KÜÇÜKÖZ    HAYIR
# 10       Akören             AVDAN     EVET
# 11       Akören            KAYASU     EVET
# 12       Akören          AHMEDİYE     EVET
# 13       Akören              ALAN     EVET
# 14       Akören           BELKUYU     EVET
# 15       Akören           ÇATÖREN     EVET
# 16       Akören             DUTLU    HAYIR
# 17       Akören          ORHANİYE     EVET
# 18       Akören       SÜLEYMANİYE     EVET
# 19       Akören             TÜLCE     EVET
# 20       Akören         KARAHÜYÜK     EVET
# ...

# %%
x = df.pop("aricilik")
df.insert(2, 'aricilik_faaliyeti', x)

# %%
df
# Out:
#        ilce_adi       mahalle_adi aricilik_faaliyeti
# 0        Ahırlı          ALİÇERÇİ              HAYIR
# 1        Ahırlı           BADEMLİ               EVET
# 2        Ahırlı         BALIKLAVA               EVET
# 3        Ahırlı           BÜYÜKÖZ               EVET
# 4        Ahırlı           ÇİFTLİK               EVET
# 5        Ahırlı           ERDOĞAN               EVET
# 6        Ahırlı        KARACAKUYU               EVET
# 7        Ahırlı           KAYACIK               EVET
# 8        Ahırlı           KURUÇAY               EVET
# 9        Ahırlı           KÜÇÜKÖZ              HAYIR
# 10       Akören             AVDAN               EVET
# 11       Akören            KAYASU               EVET
# 12       Akören          AHMEDİYE               EVET
# 13       Akören              ALAN               EVET
# 14       Akören           BELKUYU               EVET
# 15       Akören           ÇATÖREN               EVET
# 16       Akören             DUTLU              HAYIR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 770 entries, 0 to 771
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ilce_adi            770 non-null    object
#  1   mahalle_adi         770 non-null    object
#  2   aricilik_faaliyeti  770 non-null    object
# dtypes: object(3)
# memory usage: 24.1+ KB

# %%
type(df["aricilik_faaliyeti"][0])
# Out:
# str

# %%
df.to_csv("ilce_mahalle_bazli_aricilik_durum_bilgisi_2016.csv",header=True ,index=False)
df.to_excel("ilce_mahalle_bazli_aricilik_durum_bilgisi_2016.xlsx",header=True ,index=False)
