# %%
import pandas as pd

# %%
df=pd.read_csv("hizmetnoktalari.csv",sep=";")

# %%
df
# Out:
#                                                   Adı  \
# 0   Konya Büyükşehir Belediyesi Başkanlığı Kılıçar...
# 1                                   Genel Sekreterlik
# 2           Genel Sekreter Yardımcısı - Şükrü KOYUNCU
# 3                                   Hukuk Müşavirliği
# 4   Genel Sekreter Yardımcısı - Ahmet Furkan KUŞDEMİR
# 5                               KOSKI Genel Müdürlüğü
# 6                            Teftiş Kurulu Başkanlığı
# 7   Hukuk Müşavirliği Evrak Kayıt Bürosu (Dilekçe ...
# 8   Bilgi İşlem Dairesi Başkanlığı  Elkart Şube Mü...
# 9   Bilgi İşlem Dairesi Başkanlığı  Kılıçarslan El...
# 10                    Bilgi işŸlem Dairesi Başkanlığı
# 11    Basın Yayın Halkla ilişkiler Dairesi Başkanlığı
# 12         Çevre Koruma ve Kontrol Dairesi Başkanlığı
# 13      İnsan Kaynakları ve Eğitim Dairesi Başkanlığı
# 14         Çevre Koruma ve Kontrol Dairesi Başkanlığı
# 15               Destek Hizmetleri Dairesi Başkanlığı
# ...

# %%
df1=pd.read_csv("kolay.csv")

# %%
df1
# Out:
#                                                   Adı  \
# 0   Konya Büyükşehir Belediyesi Başkanlığı Kılıçar...
# 1                                   Genel Sekreterlik
# 2           Genel Sekreter Yardımcısı - Şükrü KOYUNCU
# 3                                   Hukuk Müşavirliği
# 4   Genel Sekreter Yardımcısı - Ahmet Furkan KUŞDEMİR
# 5                               KOSKİ Genel Müdürlüğü
# 6                            Teftiş Kurulu Başkanlığı
# 7   Hukuk Müşavirliği Evrak Kayıt Bürosu (Dilekçe ...
# 8   Bilgi İşlem Dairesi Başkanlığı  Elkart Şube Mü...
# 9   Bilgi İşlem Dairesi Başkanlığı  Kılıçarslan El...
# 10                     Bilgi İşlem Dairesi Başkanlığı
# 11    Basın Yayın Halkla ilişkiler Dairesi Başkanlığı
# 12         Çevre Koruma ve Kontrol Dairesi Başkanlığı
# 13      İnsan Kaynakları ve Eğitim Dairesi Başkanlığı
# 14         Çevre Koruma ve Kontrol Dairesi Başkanlığı
# 15               Destek Hizmetleri Dairesi Başkanlığı
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Adı     39 non-null     object
#  1   Adres   39 non-null     object
#  2   Enlem   39 non-null     float64
#  3   Boylam  39 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.3+ KB

# %%
type(df1["Adres"][1])
# Out:
# str

# %%
type(df1["Adı"][1])
# Out:
# str

# %%
df1.to_csv("hizmet_noktaları.csv",header=True ,index=False)
df1.to_excel("hizmet_noktaları.xlsx",header=True ,index=False)
