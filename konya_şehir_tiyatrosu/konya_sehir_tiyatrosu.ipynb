# %%
import pandas as pd

# %%
df18= pd.read_csv("138_202203_sehirtiyatrolar2018.csv",sep=";")

# %%
df18["doluluk_orani_%"]=df18["gun"]

# %%
df18
# Out:
#           tarih        gun  saat                         oyun doluluk_orani  \
# 0    24.10.2018       Salı  20.0      Abdülhamid Ateş Çemberi          100%
# 1    23.10.2018   Çarşamba  20.0      Abdülhamid Ateş Çemberi           96%
# 2    29.10.2018  Pazartesi  20.0  Asım Bir Varoluş Mücadelesi           98%
# 3    30.10.2018       Salı  20.0  Asım Bir Varoluş Mücadelesi           76%
# 4    05.11.2018  Pazartesi  20.0           Bir Yunus Hikayesi           89%
# 5    06.11.2018       Salı  20.0           Bir Yunus Hikayesi           61%
# 6    12.11.2018  Pazartesi  20.0      Abdülhamid Ateş Çemberi          100%
# 7    19.11.2018  Pazartesi  20.0  Asım Bir Varoluş Mücadelesi           43%
# 8    20.11.2018       Salı  20.0  Asım Bir Varoluş Mücadelesi           58%
# 9    27.11.2018       Salı  19.3           Bir Yunus Hikayesi           57%
# 10   28.11.2018   Çarşamba  20.0           Bir Yunus Hikayesi           51%
# ...

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     object
#  1   gun              18 non-null     object
#  2   saat             18 non-null     float64
#  3   oyun             18 non-null     object
#  4   doluluk_orani    18 non-null     object
#  5   izleyici_sayisi  18 non-null     int64
#  6   doluluk_orani_%  18 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.1+ KB

# %%
df18["tarih"]=df18["tarih"].astype("string")

# %%
for x in df18["tarih"].index:
    df18["tarih"][x]=df18["tarih"][x].replace(" ","")
    df18["tarih"][x]=df18["tarih"][x].replace(".","-")

# %%
df18["tarih"] = pd.to_datetime(df18["tarih"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\1783362938.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df18["tarih"] = pd.to_datetime(df18["tarih"])

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   gun              18 non-null     object
#  2   saat             18 non-null     float64
#  3   oyun             18 non-null     object
#  4   doluluk_orani    18 non-null     object
#  5   izleyici_sayisi  18 non-null     int64
#  6   doluluk_orani_%  18 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
for x in df18["doluluk_orani_%"].index:
    df18["doluluk_orani_%"][x]=df18["doluluk_orani"][x].replace("%","")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\2877559731.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["doluluk_orani_%"][x]=df18["doluluk_orani"][x].replace("%","")

# %%
df18
# Out:
#         tarih        gun  saat                         oyun doluluk_orani  \
# 0  2018-10-24       Salı  20.0      Abdülhamid Ateş Çemberi          100%
# 1  2018-10-23   Çarşamba  20.0      Abdülhamid Ateş Çemberi           96%
# 2  2018-10-29  Pazartesi  20.0  Asım Bir Varoluş Mücadelesi           98%
# 3  2018-10-30       Salı  20.0  Asım Bir Varoluş Mücadelesi           76%
# 4  2018-05-11  Pazartesi  20.0           Bir Yunus Hikayesi           89%
# 5  2018-06-11       Salı  20.0           Bir Yunus Hikayesi           61%
# 6  2018-12-11  Pazartesi  20.0      Abdülhamid Ateş Çemberi          100%
# 7  2018-11-19  Pazartesi  20.0  Asım Bir Varoluş Mücadelesi           43%
# 8  2018-11-20       Salı  20.0  Asım Bir Varoluş Mücadelesi           58%
# 9  2018-11-27       Salı  19.3           Bir Yunus Hikayesi           57%
# 10 2018-11-28   Çarşamba  20.0           Bir Yunus Hikayesi           51%
# 11 2018-03-12  Pazartesi  20.0      Abdülhamid Ateş Çemberi          100%
# ...

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   gun              18 non-null     object
#  2   saat             18 non-null     float64
#  3   oyun             18 non-null     object
#  4   doluluk_orani    18 non-null     object
#  5   izleyici_sayisi  18 non-null     int64
#  6   doluluk_orani_%  18 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df18["doluluk_orani_%"]=df18["doluluk_orani_%"].astype("float64")

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   gun              18 non-null     object
#  2   saat             18 non-null     float64
#  3   oyun             18 non-null     object
#  4   doluluk_orani    18 non-null     object
#  5   izleyici_sayisi  18 non-null     int64
#  6   doluluk_orani_%  18 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
df18["saat"] = pd.to_timedelta(df18["saat"] ,unit="h")

# %%
for x in df18["tarih"].index:
    df18["tarih"][x]=df18["tarih"][x]+df18["saat"][x]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\456833891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["tarih"][x]=df18["tarih"][x]+df18["saat"][x]

# %%
df18
# Out:
#                  tarih        gun            saat  \
# 0  2018-10-24 20:00:00       Salı 0 days 20:00:00
# 1  2018-10-23 20:00:00   Çarşamba 0 days 20:00:00
# 2  2018-10-29 20:00:00  Pazartesi 0 days 20:00:00
# 3  2018-10-30 20:00:00       Salı 0 days 20:00:00
# 4  2018-05-11 20:00:00  Pazartesi 0 days 20:00:00
# 5  2018-06-11 20:00:00       Salı 0 days 20:00:00
# 6  2018-12-11 20:00:00  Pazartesi 0 days 20:00:00
# 7  2018-11-19 20:00:00  Pazartesi 0 days 20:00:00
# 8  2018-11-20 20:00:00       Salı 0 days 20:00:00
# 9  2018-11-27 19:18:00       Salı 0 days 19:18:00
# 10 2018-11-28 20:00:00   Çarşamba 0 days 20:00:00
# 11 2018-03-12 20:00:00  Pazartesi 0 days 20:00:00
# 12 2018-04-12 20:00:00       Salı 0 days 20:00:00
# 13 2018-10-12 20:00:00  Pazartesi 0 days 20:00:00
# 14 2018-11-12 20:00:00       Salı 0 days 20:00:00
# 15 2018-12-24 20:00:00  Pazartesi 0 days 20:00:00
# 16 2018-12-25 20:00:00       Salı 0 days 20:00:00
# 17 2018-12-27 19:18:00   Perşembe 0 days 19:18:00
#
# ...

# %%
df18=df18.drop(columns="gun")

# %%
df18=df18.drop(columns="saat")

# %%
list=[]
list1=[]

for x in df18["doluluk_orani_%"].index:
    list.append(df18["doluluk_orani_%"][x])
    list1.append(df18["izleyici_sayisi"][x])

# %%
list
# Out:
# [100.0,
#  96.0,
#  98.0,
#  76.0,
#  89.0,
#  61.0,
#  100.0,
#  43.0,
#  58.0,
#  57.0,
#  51.0,
#  100.0,
#  100.0,
#  64.0,
#  72.0,
#  58.0,
#  49.0,
#  98.0]

# %%
list1
# Out:
# [751,
#  745,
#  748,
#  590,
#  675,
#  469,
#  769,
#  331,
#  437,
#  432,
#  389,
#  752,
#  759,
#  488,
#  544,
#  438,
#  374,
#  746]

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   oyun             18 non-null     object
#  2   doluluk_orani    18 non-null     object
#  3   izleyici_sayisi  18 non-null     int64
#  4   doluluk_orani_%  18 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 852.0+ bytes

# %%
doluluk_oranı=[]
for x in df18["doluluk_orani_%"].index:

    df18["doluluk_orani_%"][x]=(list1[x]/list[x])*100
    doluluk_oranı.append(df18["doluluk_orani_%"][x])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\2079297700.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["doluluk_orani_%"][x]=(list1[x]/list[x])*100

# %%
df18
# Out:
#                  tarih                         oyun doluluk_orani  \
# 0  2018-10-24 20:00:00      Abdülhamid Ateş Çemberi          100%
# 1  2018-10-23 20:00:00      Abdülhamid Ateş Çemberi           96%
# 2  2018-10-29 20:00:00  Asım Bir Varoluş Mücadelesi           98%
# 3  2018-10-30 20:00:00  Asım Bir Varoluş Mücadelesi           76%
# 4  2018-05-11 20:00:00           Bir Yunus Hikayesi           89%
# 5  2018-06-11 20:00:00           Bir Yunus Hikayesi           61%
# 6  2018-12-11 20:00:00      Abdülhamid Ateş Çemberi          100%
# 7  2018-11-19 20:00:00  Asım Bir Varoluş Mücadelesi           43%
# 8  2018-11-20 20:00:00  Asım Bir Varoluş Mücadelesi           58%
# 9  2018-11-27 19:18:00           Bir Yunus Hikayesi           57%
# 10 2018-11-28 20:00:00           Bir Yunus Hikayesi           51%
# 11 2018-03-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# 12 2018-04-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# ...

# %%
x
# Out:
# 17

# %%
xx=sum(df18["doluluk_orani_%"])

# %%
xx=xx/18
xx
# Out:
# 761.970861413456

# %%
for x in df18["doluluk_orani_%"].index:
    df18["doluluk_orani_%"][x]=(df18["doluluk_orani_%"][x]/df18["izleyici_sayisi"][x])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\1486510706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["doluluk_orani_%"][x]=(df18["doluluk_orani_%"][x]/df18["izleyici_sayisi"][x])

# %%
for t in df18["doluluk_orani_%"].index:

    df18["doluluk_orani_%"][t]=(list1[t]/xx)*100
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15084\2773331913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["doluluk_orani_%"][t]=(list1[t]/xx)*100

# %%
df18
# Out:
#                  tarih                         oyun doluluk_orani  \
# 0  2018-10-24 20:00:00      Abdülhamid Ateş Çemberi          100%
# 1  2018-10-23 20:00:00      Abdülhamid Ateş Çemberi           96%
# 2  2018-10-29 20:00:00  Asım Bir Varoluş Mücadelesi           98%
# 3  2018-10-30 20:00:00  Asım Bir Varoluş Mücadelesi           76%
# 4  2018-05-11 20:00:00           Bir Yunus Hikayesi           89%
# 5  2018-06-11 20:00:00           Bir Yunus Hikayesi           61%
# 6  2018-12-11 20:00:00      Abdülhamid Ateş Çemberi          100%
# 7  2018-11-19 20:00:00  Asım Bir Varoluş Mücadelesi           43%
# 8  2018-11-20 20:00:00  Asım Bir Varoluş Mücadelesi           58%
# 9  2018-11-27 19:18:00           Bir Yunus Hikayesi           57%
# 10 2018-11-28 20:00:00           Bir Yunus Hikayesi           51%
# 11 2018-03-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# 12 2018-04-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# ...

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   oyun             18 non-null     object
#  2   doluluk_orani    18 non-null     object
#  3   izleyici_sayisi  18 non-null     int64
#  4   doluluk_orani_%  18 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 852.0+ bytes

# %%
doluluk_oranı
# Out:
# [751.0,
#  776.0416666666667,
#  763.265306122449,
#  776.3157894736843,
#  758.4269662921348,
#  768.8524590163935,
#  769.0,
#  769.7674418604652,
#  753.448275862069,
#  757.8947368421052,
#  762.7450980392157,
#  752.0,
#  759.0,
#  762.5,
#  755.5555555555555,
#  755.1724137931035,
#  763.265306122449,
#  761.2244897959184]

# %%
df18["doluluk_orani"]=df18["doluluk_orani"].astype("string")

# %%
for ara in df18["doluluk_orani_%"].index:
    if df18["doluluk_orani"][ara]=="100%":
        doluluk_oranı.pop(ara)

# %%
sum(doluluk_oranı)/len(doluluk_oranı)
# Out:
# 762.6454035563314

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   oyun             18 non-null     object
#  2   doluluk_orani    18 non-null     string
#  3   izleyici_sayisi  18 non-null     int64
#  4   doluluk_orani_%  18 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1), string(1)
# memory usage: 852.0+ bytes

# %%
df18["oyun"]=df18["oyun"].astype("string")

# %%
df18
# Out:
#                  tarih                         oyun doluluk_orani  \
# 0  2018-10-24 20:00:00      Abdülhamid Ateş Çemberi          100%
# 1  2018-10-23 20:00:00      Abdülhamid Ateş Çemberi           96%
# 2  2018-10-29 20:00:00  Asım Bir Varoluş Mücadelesi           98%
# 3  2018-10-30 20:00:00  Asım Bir Varoluş Mücadelesi           76%
# 4  2018-05-11 20:00:00           Bir Yunus Hikayesi           89%
# 5  2018-06-11 20:00:00           Bir Yunus Hikayesi           61%
# 6  2018-12-11 20:00:00      Abdülhamid Ateş Çemberi          100%
# 7  2018-11-19 20:00:00  Asım Bir Varoluş Mücadelesi           43%
# 8  2018-11-20 20:00:00  Asım Bir Varoluş Mücadelesi           58%
# 9  2018-11-27 19:18:00           Bir Yunus Hikayesi           57%
# 10 2018-11-28 20:00:00           Bir Yunus Hikayesi           51%
# 11 2018-03-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# 12 2018-04-12 20:00:00      Abdülhamid Ateş Çemberi          100%
# ...

# %%
df18 = df18.drop(columns="doluluk_orani")

# %%
df18
# Out:
#                  tarih                         oyun  izleyici_sayisi  \
# 0  2018-10-24 20:00:00      Abdülhamid Ateş Çemberi              751
# 1  2018-10-23 20:00:00      Abdülhamid Ateş Çemberi              745
# 2  2018-10-29 20:00:00  Asım Bir Varoluş Mücadelesi              748
# 3  2018-10-30 20:00:00  Asım Bir Varoluş Mücadelesi              590
# 4  2018-05-11 20:00:00           Bir Yunus Hikayesi              675
# 5  2018-06-11 20:00:00           Bir Yunus Hikayesi              469
# 6  2018-12-11 20:00:00      Abdülhamid Ateş Çemberi              769
# 7  2018-11-19 20:00:00  Asım Bir Varoluş Mücadelesi              331
# 8  2018-11-20 20:00:00  Asım Bir Varoluş Mücadelesi              437
# 9  2018-11-27 19:18:00           Bir Yunus Hikayesi              432
# 10 2018-11-28 20:00:00           Bir Yunus Hikayesi              389
# 11 2018-03-12 20:00:00      Abdülhamid Ateş Çemberi              752
# 12 2018-04-12 20:00:00      Abdülhamid Ateş Çemberi              759
# ...

# %%
df18.to_excel("temiz_konya_sehir_tiyatro_excel_18.xlsx",header=True ,index=False)

# %%
df18.to_csv("temiz_konya_sehir_tiyatro_csv_18.csv",header=True ,index=False)

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tarih            18 non-null     datetime64[ns]
#  1   oyun             18 non-null     string
#  2   izleyici_sayisi  18 non-null     int64
#  3   doluluk_orani_%  18 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), string(1)
# memory usage: 708.0 bytes
