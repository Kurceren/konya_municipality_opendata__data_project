# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("35_202106_halfiyatlari.csv",sep=";")

# %%
df
# Out:
#           tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0    24.06.2021                  0.5                   9.0
# 1    21.06.2021                  0.5                   9.0
# 2    14.06.2021                  2.0                   2.5
# 3    10.06.2021                  2.0                   1.0
# 4     7.06.2021                  2.0                   1.0
# ..          ...                  ...                   ...
# 183  15.08.2019                  0.3                   4.0
# 184   8.08.2019                  0.3                   4.0
# 185   5.08.2019                  0.3                   3.0
# 186   1.08.2019                  0.3                   3.0
# 187  29.07.2019                  0.3                   3.0
#
#      semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                     2.0            1.5                  2.5
# 1                     2.0            2.0                  1.5
# 2                     1.0            2.5                  1.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 94 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tarih                   188 non-null    object
#  1   sogan_yesil_(yerli)     188 non-null    float64
#  2   turp_kirmizi_(yerli)    188 non-null    float64
#  3   semiz_otu(bag)_yerli    187 non-null    float64
#  4   armut_(yerli)           187 non-null    float64
#  5   biber_carli_(yerli)     187 non-null    float64
#  6   maydonoz_(yerli)_bag    187 non-null    float64
#  7   kiraz_(yerli)           187 non-null    float64
#  8   biber_kıl_(yerli)       187 non-null    float64
#  9   havuc                   187 non-null    float64
#  10  visne_(yerli)           187 non-null    float64
#  11  biber_sivri_(yerli)     187 non-null    float64
#  12  salatalik_(yerli)       186 non-null    float64
#  13  patlican_(yerli)        186 non-null    float64
# ...

# %%
df["tarih"]=df["tarih"].astype("string")
for a in df["tarih"].index:
    
        df["tarih"][a]=df["tarih"][a].replace(".","-")

# %%
df["tarih"] = pd.to_datetime(df["tarih"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19740\1611655992.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["tarih"] = pd.to_datetime(df["tarih"])

# %%
df
# Out:
#          tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0   2021-06-24                  0.5                   9.0
# 1   2021-06-21                  0.5                   9.0
# 2   2021-06-14                  2.0                   2.5
# 3   2021-10-06                  2.0                   1.0
# 4   2021-07-06                  2.0                   1.0
# ..         ...                  ...                   ...
# 183 2019-08-15                  0.3                   4.0
# 184 2019-08-08                  0.3                   4.0
# 185 2019-05-08                  0.3                   3.0
# 186 2019-01-08                  0.3                   3.0
# 187 2019-07-29                  0.3                   3.0
#
#      semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                     2.0            1.5                  2.5
# 1                     2.0            2.0                  1.5
# 2                     1.0            2.5                  1.5
# ...

# %%
for a in df.columns:
    if a!="tarih":
        df[a]=df[a].astype("string").str.replace(",",".")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 94 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tarih                   188 non-null    datetime64[ns]
#  1   sogan_yesil_(yerli)     188 non-null    string
#  2   turp_kirmizi_(yerli)    188 non-null    string
#  3   semiz_otu(bag)_yerli    187 non-null    string
#  4   armut_(yerli)           187 non-null    string
#  5   biber_carli_(yerli)     187 non-null    string
#  6   maydonoz_(yerli)_bag    187 non-null    string
#  7   kiraz_(yerli)           187 non-null    string
#  8   biber_kıl_(yerli)       187 non-null    string
#  9   havuc                   187 non-null    string
#  10  visne_(yerli)           187 non-null    string
#  11  biber_sivri_(yerli)     187 non-null    string
#  12  salatalik_(yerli)       186 non-null    string
#  13  patlican_(yerli)        186 non-null    string
# ...

# %%
df
# Out:
#          tarih sogan_yesil_(yerli) turp_kirmizi_(yerli) semiz_otu(bag)_yerli  \
# 0   2021-06-24                 0.5                  9.0                  2.0
# 1   2021-06-21                 0.5                  9.0                  2.0
# 2   2021-06-14                 2.0                  2.5                  1.0
# 3   2021-10-06                 2.0                  1.0                  2.5
# 4   2021-07-06                 2.0                  1.0                  2.5
# ..         ...                 ...                  ...                  ...
# 183 2019-08-15                 0.3                  4.0                  1.0
# 184 2019-08-08                 0.3                  4.0                  1.0
# 185 2019-05-08                 0.3                  3.0                  1.5
# 186 2019-01-08                 0.3                  3.0                  1.5
# 187 2019-07-29                 0.3                  3.0                  1.5
#
# ...

# %%
for col in df.columns:
    if col!="tarih":
        df[col] = pd.to_numeric(df[col], errors='coerce').astype('float64')

# %%
df
# Out:
#          tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0   2021-06-24                  0.5                   9.0
# 1   2021-06-21                  0.5                   9.0
# 2   2021-06-14                  2.0                   2.5
# 3   2021-10-06                  2.0                   1.0
# 4   2021-07-06                  2.0                   1.0
# ..         ...                  ...                   ...
# 183 2019-08-15                  0.3                   4.0
# 184 2019-08-08                  0.3                   4.0
# 185 2019-05-08                  0.3                   3.0
# 186 2019-01-08                  0.3                   3.0
# 187 2019-07-29                  0.3                   3.0
#
#      semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                     2.0            1.5                  2.5
# 1                     2.0            2.0                  1.5
# 2                     1.0            2.5                  1.5
# ...

# %%
tarih_sutunu = df[["tarih"]].copy()

# %%
tarih_sutunu
# Out:
#          tarih
# 0   2021-06-24
# 1   2021-06-21
# 2   2021-06-14
# 3   2021-10-06
# 4   2021-07-06
# ..         ...
# 183 2019-08-15
# 184 2019-08-08
# 185 2019-05-08
# 186 2019-01-08
# 187 2019-07-29
#
# [188 rows x 1 columns]

# %%
df = df.sort_values(by="tarih")
df = df.reset_index(drop=True)

# %%
df
# Out:
#          tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0   2019-01-08                  0.3                   3.0
# 1   2019-02-09                  0.3                   1.5
# 2   2019-02-12                  0.5                   1.0
# 3   2019-03-10                  0.3                   2.0
# 4   2019-04-11                  0.5                   1.0
# ..         ...                  ...                   ...
# 183 2021-11-01                  0.7                   2.0
# 184 2021-11-02                  1.0                   2.5
# 185 2021-11-03                  1.0                   2.5
# 186 2021-12-03                  0.8                   0.8
# 187 2021-12-04                  1.0                   2.0
#
#      semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                     1.5            0.5                  5.0
# 1                     0.5            0.5                  0.7
# 2                     2.0            1.0                  0.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 94 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tarih                   188 non-null    datetime64[ns]
#  1   sogan_yesil_(yerli)     188 non-null    float64
#  2   turp_kirmizi_(yerli)    188 non-null    float64
#  3   semiz_otu(bag)_yerli    187 non-null    float64
#  4   armut_(yerli)           187 non-null    float64
#  5   biber_carli_(yerli)     187 non-null    float64
#  6   maydonoz_(yerli)_bag    187 non-null    float64
#  7   kiraz_(yerli)           187 non-null    float64
#  8   biber_kıl_(yerli)       187 non-null    float64
#  9   havuc                   187 non-null    float64
#  10  visne_(yerli)           187 non-null    float64
#  11  biber_sivri_(yerli)     187 non-null    float64
#  12  salatalik_(yerli)       186 non-null    float64
#  13  patlican_(yerli)        186 non-null    float64
# ...

# %%
df.to_csv("temiz_hal_fiyatları_csv",index=False ,header=True)
